# %%
# libraries
from dotenv import load_dotenv
import os
from tavily import TavilyClient

# load environment variables from .env file
_ = load_dotenv()

# connect
client = TavilyClient(api_key=os.environ.get("TAVILY_API_KEY"))

# %%
# run search
result = client.search("What is in Nvidia's new Blackwell GPU?",
                       include_answer=True)

# print the answer
result["answer"]
# Out:
# "The new Blackwell GPU from Nvidia, specifically the Blackwell B200, is the company's most powerful single-chip GPU with 208 billion transistors. It is designed for AI applications, boasting the capability to reduce AI inference operating costs and energy consumption by up to 25 times when compared to the H100. The Blackwell GPU architecture is set to power the RTX 50-series graphics cards and is expected to be adopted by major organizations such as Amazon Web Services, Dell Technologies, Google, Meta, Microsoft, OpenAI, Oracle, Tesla, and xAI."

# %% [markdown]
# # Regular search

# %%
city = "Montreal"

query = f"""
    What is the current weather in {city}?
    Should I go outside today?
"""

# %%
import requests
from bs4 import BeautifulSoup
from duckduckgo_search import DDGS
import re

ddg = DDGS()

def search(query, max_results=6):
    try:
        results = ddg.text(query, max_results=max_results)
        return [i["href"] for i in results]
    except Exception as e:
        print(f"returning previous results due to exception reaching ddg.")
        results = [ # cover case where DDG rate limits due to high deeplearning.ai volume
            "https://weather.com/weather/today/l/USCA0987:1:US",
            "https://weather.com/weather/hourbyhour/l/54f9d8baac32496f6b5497b4bf7a277c3e2e6cc5625de69680e6169e7e38e9a8",
        ]
        return results  


for i in search(query):
    print(i)
# Out:
# https://www.accuweather.com/en/ca/montreal/h3a/weather-today/56186
# https://www.accuweather.com/en/ca/montreal/h3a/current-weather/56186
# https://www.accuweather.com/en/ca/montreal/h3a/weather-forecast/56186
# https://www.theweathernetwork.com/ca/weather/quebec/montreal
# https://weather.gc.ca/city/pages/qc-147_metric_e.html
# https://weather.gc.ca/forecast/hourly/qc-147_metric_e.html

# %%
def scrape_weather_info(url):
    """Scrape content from the given URL"""
    if not url:
        return "Weather information could not be found."
    
    # fetch data
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        return "Failed to retrieve the webpage."

    # parse result
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

# %%
# use DuckDuckGo to find websites and take the first result
url = search(query)[0]

# scrape first wesbsite
soup = scrape_weather_info(url)

print(f"Website: {url}\n\n")
print(str(soup.body)[:50000]) # limit long outputs
# Out:
# Website: https://www.accuweather.com/en/ca/montreal/h3a/weather-today/56186
#
#
# <body class="daily-detail-daynight ads-not-loaded full-animation rfphrase-disabled">
# <div class="template-root" style="display:none">
# <div class="basic-header" style="visibility: hidden;">
# <a class="pwa-top-banner" href="/pwa">
# <svg class="arrow-icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#fff" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# 		Go Back
# 	</a>
# <div class="header-outer">
# <div class="header-inner">
# <a class="header-logo" href="/">
# <svg data-eager="" height="24" viewbox="0 0 189 27" width="168" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="M183.058 22.739v-6.864c0-1.4.293-2.342.879-2.83.585-.488 1.561-.716 2.863-.716h1.269v-3.09h-1.074c-.976 0-1.822.13-2.505.422a4.054 4.054 0 0 0-1.66 1.237l-.65-1.66h-2.44v13.5h3.318zM171.28 11.743c.944 0 1.66.26 2.148.814.488.553.748 1.268.813 2.147h-6.117c.065-.911.326-1.627.814-2.147.488-.553 1.204-.814 2.147-.814h.195zm2.766 6.93c-.228.487-.553.878-.976 1.138-.423.293-.944.423-1.627.423h-.228c-1.008 0-1.757-.293-2.277-.846-.52-.553-.814-1.301-.879-2.18h9.469v-1.366c0-2.114-.553-3.806-1.66-5.042-1.106-1.269-2.635-1.887-4.555-1.887h-.228c-1.92 0-3.449.618-4.588 1.887-1.138 1.236-1.692 2.863-1.692 4.847v.878c0 .976.163 1.855.456 2.668a5.877 5.877 0 0 0 1.269 2.082 5.83 5.83 0 0 0 2.017 1.366c.814.325 1.692.488 2.7.488h.229c1.269 0 2.342-.26 3.253-.748s1.66-1.236 2.213-2.245l-2.896-1.464zm-20.271 4.066v-7.873c.033-.91.26-1.659.716-2.244.455-.586 1.139-.879 1.985-.879h.325c.748 0 1.334.228 1.757.716.456.455.65 1.236.65 2.31v8.002h3.32v-8.588c0-1.594-.423-2.863-1.302-3.838-.878-.976-2.017-1.464-3.481-1.464h-.39c-.717 0-1.4.13-2.018.423a5.332 5.332 0 0 0-1.627 1.17V3.84h-3.319v18.9h3.384zm-8.688-2.96c-.227-.196-.325-.554-.325-1.074v-6.799h3.254V9.239h-3.254v-2.96h-2.83l-.359 2.96h-2.212v2.667h2.115v6.831c0 1.236.293 2.212.878 2.928.586.716 1.595 1.074 2.994 1.074h2.635V20.07h-1.92c-.455 0-.78-.098-.976-.293zm-13.828.52c-.683 0-1.204-.13-1.562-.39-.358-.26-.553-.651-.553-1.14v-.097c0-.488.195-.91.618-1.236.39-.325 1.106-.488 2.148-.488h2.472v.488c0 .976-.26 1.692-.78 2.147-.521.456-1.237.716-2.083.716h-.26zm-.65 2.797c.878 0 1.626-.162 2.31-.488.683-.325 1.236-.813 1.691-1.496l.553 1.66h2.506v-8.85c0-1.658-.488-2.927-1.464-3.773-.977-.845-2.343-1.268-4.068-1.268h-.325c-1.562 0-2.798.325-3.71.943-.91.65-1.496 1.431-1.756 2.342l2.928 1.204c.163-.456.456-.813.846-1.139.39-.292.944-.455 1.627-.455h.325c.781 0 1.367.195 1.725.553.39.39.553.91.553 1.594v.683h-2.408c-1.985 0-3.481.39-4.523 1.171-1.04.78-1.561 1.822-1.561 3.09v.196c0 1.268.39 2.244 1.17 2.992.782.716 1.888 1.106 3.32 1.106h.26v-.065zm-12.495-11.353c.943 0 1.659.26 2.147.814.488.553.748 1.268.813 2.147h-6.117c.065-.911.326-1.627.814-2.147.488-.553 1.204-.814 2.147-.814h.196zm2.765 6.93c-.228.487-.553.878-.976 1.138-.423.293-.943.423-1.627.423h-.228c-1.008 0-1.757-.293-2.277-.846-.52-.553-.814-1.301-.879-2.18h9.469v-1.366c0-2.114-.553-3.806-1.66-5.042-1.106-1.269-2.635-1.887-4.555-1.887h-.26c-1.92 0-3.45.618-4.588 1.887-1.139 1.236-1.692 2.863-1.692 4.847v.878c0 .976.163 1.855.455 2.668a5.877 5.877 0 0 0 1.27 2.082 5.83 5.83 0 0 0 2.017 1.366c.813.325 1.692.488 2.7.488h.228c1.27 0 2.343-.26 3.254-.748s1.66-1.236 2.213-2.245l-2.864-1.464zM95.76 22.738l3.97-13.76 3.774 13.76h3.026l5.434-18.673V3.84h-3.254l-3.58 13.37-3.513-13.37h-3.58L94.36 17.436 90.878 3.84h-3.416v.227l5.206 18.673h3.091zm-21.312-13.5v8.555c0 1.594.423 2.863 1.301 3.839.879.975 2.018 1.463 3.482 1.463h.358c.813 0 1.561-.162 2.212-.488.684-.325 1.237-.813 1.692-1.43l.553 1.56h2.473v-13.5h-3.286v7.873c-.033.91-.26 1.659-.748 2.244-.489.586-1.14.879-2.018.879h-.325c-.716 0-1.302-.228-1.757-.716-.456-.455-.684-1.236-.684-2.31V9.206h-3.253v.033zm-3.645.553c-.91-.586-2.082-.879-3.546-.879h-.228c-1.92 0-3.449.553-4.588 1.692-1.139 1.138-1.692 2.635-1.692 4.522v1.724c0 1.886.553 3.415 1.692 4.521 1.139 1.139 2.636 1.692 4.588 1.692h.228c1.334 0 2.44-.26 3.319-.78.878-.521 1.561-1.27 2.082-2.31l-2.733-1.53a3.17 3.17 0 0 1-.976 1.27c-.423.325-.976.487-1.692.487h-.228c-1.041 0-1.79-.325-2.278-.943-.488-.618-.715-1.431-.715-2.44V15.16c0-1.008.227-1.822.715-2.44.488-.618 1.237-.943 2.278-.943h.228c.716 0 1.301.163 1.724.488.423.325.749.78.976 1.334l2.864-1.367c-.423-1.008-1.107-1.854-2.018-2.44zm-13.308 0c-.91-.586-2.082-.879-3.546-.879h-.228c-1.92 0-3.449.553-4.588 1.692-1.139 1.138-1.692 2.635-1.692 4.522v1.724c0 1.886.553 3.415 1.692 4.521 1.139 1.139 2.636 1.692 4.588 1.692h.228c1.334 0 2.44-.26 3 ...
# </a>
# <a class="header-city-link" href="/en/ca/montreal/h3a/weather-forecast/56186">
# <h1 class="header-loc">Montreal, Quebec</h1>
# <span class="header-temp">19°<span class="unit">C</span></span>
# <svg class="header-weather-icon" data-src="/images/weathericons/1.svg" height="27" viewbox="0 0 288 288" width="27"><g fill="none" fill-rule="evenodd" stroke="#FF8700" stroke-width="9.6"><path d="M144 0v48M144 240v48M0 144h48M211.872 76.128l33.936-33.936M245.808 245.808l-33.936-33.936M76.128 76.128 42.192 42.192"></path><circle cx="144" cy="144" r="76.8"></circle><path d="m76.128 211.872-33.936 33.936M240 144h48"></path></g></svg>
# </a>
# <div class="pull-right">
# <div class="header-search-bar search-bar">
# <div class="searchbar-inner">
# <svg class="icon-search" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.186 13.554c-3.462 0-6.303-2.869-6.303-6.359C.883 3.681 3.724.837 7.186.837c3.437 0 6.278 2.844 6.278 6.358 0 3.49-2.865 6.359-6.278 6.359zm5.323-1.602a7.176 7.176 0 0 0 1.815-4.757c0-3.968-3.2-7.195-7.138-7.195C3.223 0 0 3.227 0 7.195c0 3.944 3.223 7.171 7.186 7.171a7.058 7.058 0 0 0 4.75-1.84L17.427 18l.573-.55-5.49-5.498z" transform="translate(3 3)"></path></svg>
# <form action="/en/search-locations" class="search-form" method="GET">
# <input autocomplete="off" class="search-input" data-alternative-placeholder="Search" data-placeholder="Address, City or Zip Code" name="query" placeholder="Address, City or Zip Code" type="text"/>
# </form>
# <svg class="clear-icon close-icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd" transform="translate(-1 -1)"><rect height="24" rx="1" transform="rotate(45 10 10)" width="2" x="9" y="-2"></rect><rect height="24" rx="1" transform="rotate(-45 10 10)" width="2" x="9" y="-2"></rect></g></svg>
# <div class="search-options">
# <div class="dropdown-legacy left-bar">
# <div class="displayed-item">
# <span>
# 			Location
# 		</span>
# <svg aria-labelledby="chevronSVG" class="icon-chevron arrow" height="6" role="img" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg">
# <title id="chevronSVG">Chevron down</title>
# <path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z"></path>
# </svg>
# </div>
# <div class="items">
# <a class="item active" value="/en/search-locations">
# <span>Location</span>
# <svg alt="" class="item-icon icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z"></path><use fill="#000" fill-rule="evenodd"></use></svg>
# </a>
# <a class="item" value="/en/search-news">
# <span>News</span>
# <svg alt="" class="item-icon icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z"></path><use fill="#000" fill-rule="evenodd"></use></svg>
# </a>
# <a class="item" value="/en/search-video">
# <span>Videos</span>
# <svg alt="" class="item-icon icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z"></path><use fill="#000" fill-rule="evenodd"></use></svg>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="search-bar-dropdown">
# <div class="use-current-location">
# <svg class="icon-gps gps-icon" height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><g fill="#000" fill-opacity="0.995941" fill-rule="evenodd" id="Symbols" stroke="none" stroke-width="1"><g id="ICONS-/-Menu-/-GPS"><polygon id="Triangle" points="9.44615242 -1.13878407 15.4461524 15.8612159 9.44615242 12.4612159 3.44615242 15.8612159" transform="translate(9.446152, 7.361216) rotate(-330.000000) translate(-9.446152, -7.361216) "></polygon></g></g></svg>
# <span>Use Current Location</span>
# </div>
# <div class="recent-locations-dropdown">
# <div class="recent-title">Recent</div>
# <a class="recent-location" data-fetch="false" data-location-key="56186" href="/web-api/three-day-redirect?key=56186&amp;target=">
# <div class="recent-location__title-wrapper">
# <p class="recent-location__name">Montreal</p>
# <p class="recent-location__admin">Quebec</p>
# </div>
# <svg class="recent-location__icon" data-src="/images/weathericons/1.svg" height="32" viewbox="0 0 288 288" width="32"><g fill="none" fill-rule="evenodd" stroke="#FF8700" stroke-width="9.6"><path d="M144 0v48M144 240v48M0 144h48M211.872 76.128l33.936-33.936M245.808 245.808l-33.936-33.936M76.128 76.128 42.192 42.192"></path><circle cx="144" cy="144" r="76.8"></circle><path d="m76.128 211.872-33.936 33.936M240 144h48"></path></g></svg>
# <span class="recent-location__temp">19°</span>
# </a>
# </div>
# <div class="search-results">
# <div class="results-container"></div>
# </div>
# <div class="search-results no-search-result hidden">
# <div class="results-container">
# <div class="search-bar-result search-result no-result">
# <div class="no-result-headline">No results found.</div>
# <div class="no-result-text">Try searching for a city, zip code or point of interest.</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <a class="video-wall-icon" href="/en/videos">
# <svg height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M17.0946 14.2044H0.75V1.5H17.0946V14.2044ZM16.2751 13.3847H1.56964V2.31948H16.2751V13.3847ZM7.4518 5.42938V10.2508L11.1643 7.8401L7.4518 5.42938ZM6.63216 3.91071L12.2491 7.55081V8.10528L6.63216 11.7696V3.91071Z" fill="white" fill-rule="evenodd"></path><path clip-rule="evenodd" d="M4.82422 16.5884H13.0207V15.7687H4.82422V16.5884Z" fill="white" fill-rule="evenodd"></path></svg>
# </a>
# <svg class="hamburger-button icon-hamburger" data-qa="navigationMenu" height="18" viewbox="0 0 24 24" width="18" xmlns="http://www.w3.org/2000/svg">
# <defs>
# <path d="M10 12v1H0v-1h10zm6-6v1H0V6h16zm0-6v1H0V0h16z" id="svghamburger"></path>
# </defs>
# <use fill="#FFF" fill-rule="evenodd" transform="matrix(-1 0 0 1 20 6)" xlink:href="#svghamburger"></use></svg>
# <svg class="close-button close-icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd" transform="translate(-1 -1)"><rect height="24" rx="1" transform="rotate(45 10 10)" width="2" x="9" y="-2"></rect><rect height="24" rx="1" transform="rotate(-45 10 10)" width="2" x="9" y="-2"></rect></g></svg>
# </div>
# </div>
# </div>
# <div class="header-menu">
# <div class="settings-link">
# <a href="/en/settings">
# <svg class="icon-settings" fill="#FFF" height="25" viewbox="0 0 24 25" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M13.677.107l.871 2.674c.775.225 1.549.483 2.162.902l2.58-1.32 2.452 2.447-1.29 2.578c.354.612.645 1.353.87 2.094l2.678.902v3.414l-2.645.838c-.258.773-.549 1.578-.903 2.255l1.29 2.48-2.452 2.449-2.58-1.224c-.645.386-1.387.676-2.162.902l-.87 2.609h-3.42l-.903-2.61c-.742-.225-1.484-.482-2.161-.934L4.742 21.82 2.29 19.372l1.29-2.449c-.386-.676-.677-1.45-.903-2.255L0 13.798v-3.447l2.71-.902c.193-.74.451-1.481.87-2.094L2.29 4.843l2.452-2.449 2.452 1.289c.677-.387 1.419-.677 2.16-.902l.904-2.674h3.42zm-.838 1.128h-1.807l-.806 2.448-.549.193c-.677.194-1.354.419-1.935.773l-.548.29-2.29-1.16L3.58 5.1l1.225 2.384-.354.548c-.323.483-.581 1.127-.71 1.74l-.13.612-2.515.805v1.804l2.451.805.194.58c.193.677.42 1.385.774 1.965l.29.548-1.16 2.287L4.967 20.5l2.322-1.16.549.355c.58.354 1.226.612 1.903.773l.548.193.775 2.32h1.838l.774-2.417.581-.128c.677-.194 1.323-.42 1.903-.741l.484-.322 2.42 1.127 1.322-1.32-1.161-2.288.29-.483c.323-.645.58-1.353.774-2.062l.194-.58 2.42-.74V11.19l-2.452-.805-.194-.548c-.193-.677-.42-1.32-.742-1.836l-.29-.548 1.161-2.384-1.322-1.353-2.388 1.256-.548-.354a7.5 7.5 0 00-1.903-.74l-.58-.194-.807-2.448zm-.871 5.38c3.032 0 5.548 2.448 5.548 5.508 0 3.028-2.516 5.541-5.548 5.541-3.065 0-5.516-2.545-5.516-5.54a5.49 5.49 0 015.516-5.51zm0 1.063c-2.323 0-4.355 2.093-4.355 4.445 0 2.352 2.032 4.446 4.355 4.446 2.322 0 4.387-2.126 4.387-4.446 0-2.352-2.065-4.445-4.387-4.445z"></path></svg>
# 				settings
# 			</a>
# <svg class="close-button desktop-close close-icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd" transform="translate(-1 -1)"><rect height="24" rx="1" transform="rotate(45 10 10)" width="2" x="9" y="-2"></rect><rect height="24" rx="1" transform="rotate(-45 10 10)" width="2" x="9" y="-2"></rect></g></svg>
# </div>
# <div class="header-loc-weather">Montreal, Quebec Weather</div>
# <a class="header-link" data-ga-page-id="today" data-page-id="three-day" href="/en/ca/montreal/h3a/weather-forecast/56186">Today</a>
# <a class="header-link nav-red-dot hidden winter-link" data-ga-page-id="wintercast" data-page-id="wintercast" href="/en/ca/montreal/h3a/winter-weather-forecast/56186">WinterCast</a>
# <a class="header-link nav-red-tropical-image northern side-item hidden tropical-link" data-ga-page-id="local_{stormName}_tracker" data-page-id="tropical" href="/en/ca/montreal/h3a/tropical-weather-forecast/56186?eventkey={eventkey}">Local {stormName} Tracker</a>
# <a class="header-link" data-ga-page-id="hourly" data-page-id="hourly" href="/en/ca/montreal/h3a/hourly-weather-forecast/56186">Hourly</a>
# <a class="header-link" data-ga-page-id="daily" data-page-id="daily" href="/en/ca/montreal/h3a/daily-weather-forecast/56186">Daily</a>
# <a class="header-link" data-ga-page-id="radar" data-page-id="city-radar" href="/en/ca/montreal/h3a/weather-radar/56186">Radar</a>
# <a class="header-link" data-ga-page-id="minutecast" data-page-id="minutecast" href="/en/ca/montreal/h3a/minute-weather-forecast/56186">MinuteCast</a>
# <a class="header-link" data-ga-page-id="monthly" data-page-id="monthly" href="/en/ca/montreal/h3a/june-weather/56186">Monthly</a>
# <a class="header-link" data-ga-page-id="air_quality" data-page-id="air-quality" href="/en/ca/montreal/h3a/air-quality-index/56186">Air Quality</a>
# <a class="header-link" data-ga-page-id="health_and_activities" data-page-id="lifestyle-home" href="/en/ca/montreal/h3a/health-activities/56186">Health &amp; Activities</a>
# <div class="more-cta-links">
# <h2 class="more-cta-title">
# <p>Around the Globe</p>
# </h2>
# <a class="cta-link" data-ga-page-id="hurricane_tracker" data-page-id="hurricane" href="/en/hurricane">
# <h3 class="cta-text">Hurricane Tracker</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-ga-page-id="severe_weather" data-page-id="severe-weather" href="/en/ca/severe-weather">
# <h3 class="cta-text">Severe Weather</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-ga-page-id="radar_and_maps" data-page-id="map-radar" href="/en/ca/quebec/weather-radar">
# <h3 class="cta-text">Radar &amp; Maps</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <div class="sublink-container">
# <div class="sublink-header">
# <div class="sublink-title">News</div>
# <svg class="icon-chevron chevron-icon down" height="6" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg"><path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z"></path></svg>
# </div>
# <a class="cta-link" data-ga-page-id="news_and_features" data-page-id="news" href="/en/weather-news">
# <h3 class="cta-text">News &amp; Features</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-ga-page-id="astronomy" data-page-id="content-landing" href="/en/space-news">
# <h3 class="cta-text">Astronomy</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-ga-page-id="business" data-page-id="content-landing" href="/en/business">
# <h3 class="cta-text">Business</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-ga-page-id="climate" data-page-id="content-landing" href="/en/climate">
# <h3 class="cta-text">Climate</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-ga-page-id="health" data-page-id="content-landing" href="/en/health-wellness">
# <h3 class="cta-text">Health</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-ga-page-id="recreation" data-page-id="content-landing" href="/en/leisure-recreation">
# <h3 class="cta-text">Recreation</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-ga-page-id="sports" data-page-id="content-landing" href="/en/sports">
# <h3 class="cta-text">Sports</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-ga-page-id="travel" data-page-id="content-landing" href="/en/travel">
# <h3 class="cta-text">Travel</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# </div>
# <a class="cta-link" data-ga-page-id="video" data-page-id="video-wall" href="/en/videos">
# <h3 class="cta-text">Video</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-ga-page-id="winter_center" data-page-id="winter-weather" href="/en/ca/winter-weather">
# <h3 class="cta-text">Winter Center</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# </div>
# </div>
# </div>
# <div class="header-placeholder"></div>
# <div class="page-subnav">
# <div class="subnav secondary-nav" data-gatype="city">
# <div class="overflow overflow-left" data-qa="leftArrow">
# <svg class="arrow chevron-icon left" height="6" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg"><path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z"></path></svg>
# </div>
# <div class="overflow overflow-right" data-qa="rightArrow">
# <svg class="arrow chevron-icon right" height="6" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg"><path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z"></path></svg>
# </div>
# <div class="subnav-items">
# <a class="subnav-item" data-gaid="now" data-pageid="three-day" data-qa="now" href="/en/ca/montreal/h3a/weather-forecast/56186">
# <span>Today</span>
# </a>
# <a class="subnav-item" data-gaid="hourly" data-pageid="hourly" data-qa="hourly" href="/en/ca/montreal/h3a/hourly-weather-forecast/56186">
# <span>Hourly</span>
# </a>
# <a class="subnav-item" data-gaid="daily" data-pageid="daily" data-qa="daily" href="/en/ca/montreal/h3a/daily-weather-forecast/56186">
# <span>Daily</span>
# </a>
# <a class="subnav-item" data-gaid="radar" data-pageid="city-radar" data-qa="radar" href="/en/ca/montreal/h3a/weather-radar/56186">
# <span>Radar</span>
# </a>
# <a class="subnav-item" data-gaid="minutecast" data-pageid="minutecast" data-qa="minutecast" href="/en/ca/montreal/h3a/minute-weather-forecast/56186">
# <span>MinuteCast</span>
# </a>
# <a class="subnav-item" data-gaid="monthly" data-pageid="monthly" data-qa="monthly" href="/en/ca/montreal/h3a/june-weather/56186">
# <span>Monthly</span>
# </a>
# <a class="subnav-item" data-gaid="airQuality" data-pageid="air-quality" data-qa="airQuality" href="/en/ca/montreal/h3a/air-quality-index/56186">
# <span>Air Quality</span>
# </a>
# <a class="subnav-item" data-gaid="lifestyles" data-pageid="lifestyle-home" data-qa="lifestyles" href="/en/ca/montreal/h3a/health-activities/56186">
# <span>Health &amp; Activities</span>
# </a>
# <a class="subnav-item" data-gaid="for-business" data-pageid="for-business" data-qa="for-business" href="https://afb.accuweather.com">
# <span>For Business</span>
# </a>
# <div class="subnav-item filler"></div>
# </div>
# </div>
# </div>
# <div class="glacier-ad unrendered top config-top content-module" data-ad-type="top" data-viewport="tablet desktop" id="top"></div>
# <div class="glacier-ad unrendered oop config-oop" data-ad-type="oop" data-viewport="" id="oop"></div>
# <div class="glacier-ad unrendered interstitial config-interstitial" data-ad-type="interstitial" data-viewport="" id="interstitial"></div>
# <div class="two-column-page-content">
# <div class="page-column-1">
# <div class="page-content content-module">
# <div class="subnav-pagination">
# <a class="hidden" href="">
# <svg class="pagination-button chevron-icon left" height="6" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg"><path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z"></path></svg>
# </a>
# <div>Friday, June 7</div>
# <a class="" href="/en/ca/montreal/h3a/weather-tomorrow/56186">
# <svg class="pagination-button chevron-icon right" height="6" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg"><path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z"></path></svg>
# </a>
# </div>
# <div class="half-day-card content-module">
# <div class="half-day-card-header">
# <div class="half-day-card-header__title">
# <h2 class="title">Day</h2>
# <span class="short-date">
# 				6/7
# 			</span>
# </div>
# <div class="half-day-card-header__content">
# <div class="weather">
# <svg class="icon" data-src="/images/weathericons/15.svg" height="128" viewbox="0 0 288 288" width="128"><g fill="none" fill-rule="evenodd" stroke-width="9.796"><path d="m135.861 258.506 37.42-64.065h-42.514l37.42-64.163" stroke="#FF8700"></path><path d="M167.698 167.698h37.175c31.109 0 56.327-25.218 56.327-56.327 0-31.108-25.218-56.326-56.327-56.326h-9.649c-17.997-21.189-47.006-29.414-73.446-20.826-26.44 8.588-45.079 32.29-47.19 60.01H62.784c-20.288 0-36.735 16.446-36.735 36.734s16.447 36.735 36.735 36.735h61.714" stroke="#BABABA"></path></g></svg>
# <div class="temperature">
# 					22°<span class="hi-lo-label">Hi</span>
# </div>
# </div>
# <div class="real-feel">
# <div>
# 					RealFeel®
# 					23°
#
# <div class="label-tooltip" data-js="prevent-accordion-toggle">
# <div class="label clickable">Pleasant</div>
# <div class="label-tooltip-overlay">
# <div class="label-tooltip-header spaced-content">
# <span>RealFeel Guide</span>
# <svg class="close-icon" height="14" viewbox="0 0 18 18" width="14" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd" transform="translate(-1 -1)"><rect height="24" rx="1" transform="rotate(45 10 10)" width="2" x="9" y="-2"></rect><rect height="24" rx="1" transform="rotate(-45 10 10)" width="2" x="9" y="-2"></rect></g></svg>
# </div>
# <div class="label-tooltip-content">
# <div class="label-tooltip-content__subtitle spaced-content">
# <div>Pleasant</div>
# <div class="label-tooltip-content__reference">17° to 26°</div>
# </div>
# <div class="label-tooltip-content__content">Most consider this temperature range ideal.</div>
# </div>
# <a class="label-tooltip-cta" href="/en/realfeel-guide">LEARN MORE <svg class="icon-arrow" height="12" viewbox="0 0 12 12" width="12" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg></a>
# </div>
# </div>
# </div>
# <div class="realfeel-shade-details">
# <div>
# 						RealFeel Shade™
# 						21°
#
# <div class="label-tooltip" data-js="prevent-accordion-toggle">
# <div class="label clickable">Pleasant</div>
# <div class="label-tooltip-overlay">
# <div class="label-tooltip-header spaced-content">
# <span>RealFeel Guide</span>
# <svg class="close-icon" height="14" viewbox="0 0 18 18" width="14" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd" transform="translate(-1 -1)"><rect height="24" rx="1" transform="rotate(45 10 10)" width="2" x="9" y="-2"></rect><rect height="24" rx="1" transform="rotate(-45 10 10)" width="2" x="9" y="-2"></rect></g></svg>
# </div>
# <div class="label-tooltip-content">
# <div class="label-tooltip-content__subtitle spaced-content">
# <div>Pleasant</div>
# <div class="label-tooltip-content__reference">17° to 26°</div>
# </div>
# <div class="label-tooltip-content__content">Most consider this temperature range ideal.</div>
# </div>
# <a class="label-tooltip-cta" href="/en/realfeel-guide">LEARN MORE <svg class="icon-arrow" height="12" viewbox="0 0 12 12" width="12" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="half-day-card-content">
# <div class="phrase">Mainly cloudy with a couple of thundershowers</div>
# <div class="panels">
# <div class="left">
# <p class="panel-item">Max UV Index<span class="value">4 Moderate</span></p>
# <p class="panel-item">Wind<span class="value">SW 11 km/h</span></p>
# <p class="panel-item">Wind Gusts<span class="value">35 km/h</span></p>
# <p class="panel-item">Probability of Precipitation<span class="value">84%</span></p>
# <p class="panel-item">Probability of Thunderstorms<span class="value">26%</span></p>
# </div>
# <div class="right">
# <p class="panel-item">Precipitation<span class="value">7.9 mm</span></p>
# <p class="panel-item">Rain<span class="value">7.9 mm</span></p>
# <p class="panel-item">Hours of Precipitation<span class="value">4</span></p>
# <p class="panel-item">Hours of Rain<span class="value">4</span></p>
# <p class="panel-item">Cloud Cover<span class="value">76%</span></p>
# </div>
# </div>
# </div>
# <div class="quarter-day-ctas">
# <h3>
# <a class="quarter-day-cta spaced-content" href="/en/ca/montreal/h3a/morning-weather-forecast/56186?day=1">
# 				Morning
# 				<svg height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# </h3>
# <h3>
# <a class="quarter-day-cta spaced-content" href="/en/ca/montreal/h3a/afternoon-weather-forecast/56186?day=1">
# 				Afternoon
# 				<svg height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# </h3>
# </div>
# </div>
# <div class="glacier-ad unrendered native config-native content-module" data-ad-type="native" data-viewport="" id="native"></div>
# <div class="half-day-card content-module">
# <div class="half-day-card-header">
# <div class="half-day-card-header__title">
# <h2 class="title">Night</h2>
# <span class="short-date">
# 				6/7
# 			</span>
# </div>
# <div class="half-day-card-header__content">
# <div class="weather">
# <svg class="icon" data-src="/images/weathericons/39.svg" height="128" viewbox="0 0 288 288" width="128"><g fill="none" fill-rule="evenodd" stroke-width="9.789"><path d="m31.089 259.47 21.537-36.906M103.972 259.47l19.97-34.165M56.835 278.12l32.452-55.556" stroke="#288ADB"></path><path d="M95.504 202.79a116.593 116.593 0 0 0 184.727-17.622 113.656 113.656 0 0 1-94.126-20.998M151.157 118.992A111.943 111.943 0 0 1 163.443 10.23c-51.65 7.733-91.741 49.067-97.895 100.929" stroke="#686763" stroke-linejoin="bevel"></path><path d="M144.06 202.79c22.756-.776 40.803-19.448 40.803-42.218 0-22.77-18.047-41.442-40.804-42.217h-7.244a51.346 51.346 0 0 0-90.454 29.369H37.5a27.557 27.557 0 1 0 0 55.065H144.06Z" stroke="#BABABA"></path></g></svg>
# <div class="temperature">
# 					14°<span class="hi-lo-label">Lo</span>
# </div>
# </div>
# <div class="real-feel">
# <div>
# 					RealFeel®
# 					13°
#
# <div class="label-tooltip" data-js="prevent-accordion-toggle">
# <div class="label clickable">Cool</div>
# <div class="label-tooltip-overlay">
# <div class="label-tooltip-header spaced-content">
# <span>RealFeel Guide</span>
# <svg class="close-icon" height="14" viewbox="0 0 18 18" width="14" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd" transform="translate(-1 -1)"><rect height="24" rx="1" transform="rotate(45 10 10)" width="2" x="9" y="-2"></rect><rect height="24" rx="1" transform="rotate(-45 10 10)" width="2" x="9" y="-2"></rect></g></svg>
# </div>
# <div class="label-tooltip-content">
# <div class="label-tooltip-content__subtitle spaced-content">
# <div>Cool</div>
# <div class="label-tooltip-content__reference">11° to 16°</div>
# </div>
# <div class="label-tooltip-content__content">Light jacket or sweater may be appropriate.</div>
# </div>
# <a class="label-tooltip-cta" href="/en/realfeel-guide">LEARN MORE <svg class="icon-arrow" height="12" viewbox="0 0 12 12" width="12" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="half-day-card-content">
# <div class="phrase">Clear to partly cloudy with a shower in spots</div>
# <div class="panels">
# <div class="left">
# <p class="panel-item">Wind<span class="value">WSW 9 km/h</span></p>
# <p class="panel-item">Wind Gusts<span class="value">33 km/h</span></p>
# <p class="panel-item">Probability of Precipitation<span class="value">40%</span></p>
# <p class="panel-item">Probability of Thunderstorms<span class="value">8%</span></p>
# <p class="panel-item">Precipitation<span class="value">0.5 mm</span></p>
# </div>
# <div class="right">
# <p class="panel-item">Rain<span class="value">0.5 mm</span></p>
# <p class="panel-item">Hours of Precipitation<span class="value">1</span></p>
# <p class="panel-item">Hours of Rain<span class="value">1</span></p>
# <p class="panel-item">Cloud Cover<span class="value">25%</span></p>
# </div>
# </div>
# </div>
# <div class="quarter-day-ctas">
# <h3>
# <a class="quarter-day-cta spaced-content" href="/en/ca/montreal/h3a/evening-weather-forecast/56186?day=1">
# 				Evening
# 				<svg height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# </h3>
# <h3>
# <a class="quarter-day-cta spaced-content" href="/en/ca/montreal/h3a/overnight-weather-forecast/56186?day=1">
# 				Overnight
# 				<svg height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# </h3>
# </div>
# </div>
# <script>
# 		window.collapseConnatix = () => {
# 			const connatixEl = document.getElementById('connatix')
# 			if(connatixEl) {
# 				connatixEl.style.display = "none";
# 			}
# 		}
# 	</script>
# <div class="content-module" id="connatix"></div>
# <div class="sunrise-sunset content-module">
# <h2 class="sunrise-sunset__title">
# 		Sun &amp; Moon
# 	</h2>
# <div class="sunrise-sunset__body">
# <div class="sunrise-sunset__item">
# <img aria-hidden="true" class="sunrise-sunset__icon sun-icon" height="40" src="/images/whiteweathericons/1.svg" width="40"/>
# <span class="sunrise-sunset__phrase">15 hrs 35 mins</span>
# <div class="sunrise-sunset__times">
# <div class="sunrise-sunset__times-item">
# <span class="sunrise-sunset__times-label">Rise</span>
# <span class="sunrise-sunset__times-value">5:06 AM</span>
# </div>
# <div class="sunrise-sunset__times-item">
# <span class="sunrise-sunset__times-label">Set</span>
# <span class="sunrise-sunset__times-value">8:41 PM</span>
# </div>
# </div>
# </div>
# <div class="sunrise-sunset__item">
# <img aria-hidden="true" class="sunrise-sunset__icon" height="40" src="/images/moon-phases/light/WaxingCrescent.svg" width="40"/>
# <span class="sunrise-sunset__phrase">Waxing Crescent</span>
# <div class="sunrise-sunset__times">
# <div class="sunrise-sunset__times-item">
# <span class="sunrise-sunset__times-label">Rise</span>
# <span class="sunrise-sunset__times-value">5:29 AM</span>
# </div>
# <div class="sunrise-sunset__times-item">
# <span class="sunrise-sunset__times-label">Set</span>
# <span class="sunrise-sunset__times-value">10:33 PM</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="temp-history content-module">
# <div class="history">
# <div class="title-row">
# <h2>Temperature History</h2> <span class="header-date">6/7</span>
# </div>
# <div class="label-row">
# <div class="label"></div>
# <div class="temp-label">High</div>
# <div class="temp-label">Low</div>
# </div>
# <div class="row first">
# <div class="label">Forecast</div>
# <div class="temperature">22°</div>
# <div class="temperature">14°</div>
# </div>
# <div class="row">
# <div class="label">Average</div>
# <div class="temperature">24°</div>
# <div class="temperature">11°</div>
# </div>
# <div class="row">
# <div class="label">Last Year</div>
# <div class="temperature">16°</div>
# <div class="temperature">11°</div>
# </div>
# </div>
# </div>
# <div class="more-cta-links">
# <h2 class="more-cta-title">
# <p>Further Ahead</p>
# </h2>
# <a class="cta-link" data-ga-page-id="" data-page-id="" href="/en/ca/montreal/h3a/hourly-weather-forecast/56186">
# <h3 class="cta-text">Hourly</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-ga-page-id="" data-page-id="" href="/en/ca/montreal/h3a/daily-weather-forecast/56186">
# <h3 class="cta-text">Daily</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-ga-page-id="" data-page-id="" href="/en/ca/montreal/h3a/june-weather/56186">
# <h3 class="cta-text">Monthly</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# </div>
# </div>
# <div class="more-cta-links">
# <h2 class="more-cta-title">
# <p>Around the Globe</p>
# </h2>
# <a class="cta-link" data-ga-page-id="hurricane_tracker" data-page-id="hurricane" href="/en/hurricane">
# <h3 class="cta-text">Hurricane Tracker</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-ga-page-id="severe_weather" data-page-id="severe-weather" href="/en/ca/severe-weather">
# <h3 class="cta-text">Severe Weather</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-ga-page-id="radar_and_maps" data-page-id="map-radar" href="/en/ca/quebec/weather-radar">
# <h3 class="cta-text">Radar &amp; Maps</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-ga-page-id="" data-page-id="" href="/en/weather-news">
# <h3 class="cta-text">News</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-ga-page-id="video" data-page-id="video-wall" href="/en/videos">
# <h3 class="cta-text">Video</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-ga-page-id="winter_center" data-page-id="winter-weather" href="/en/ca/winter-weather">
# <h3 class="cta-text">Winter Center</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# </div>
# </div>
# <div class="page-column-2">
# <div class="right-rail left-align-children">
# <div class="glacier-ad unrendered top_right config-top_right content-module" data-ad-type="top_right" data-viewport="tablet desktop" id="top_right"></div>
# <div class="zone-rightRail1 content-module">
# <div class="thumbnail-right-rail">
# <p class="title">Top Stories</p>
# <a class="right-rail-article right-rail-ga" data-ga-action="Right Rail Click Editorial" data-ga-display-type="RightRailThumbnail" data-ga-label="Severe storms and downpours to return to south-central US" data-ga-section="Top Stories" href="https://www.accuweather.com/en/severe-weather/severe-storms-and-downpours-to-return-to-southern-plains-lower-mississippi-valley/1657316">
# <div class="right-rail-article__meta">
# <p class="right-rail-article__category">Severe Weather</p>
# <p class="right-rail-article__title">Severe storms and downpours to return to south-central US</p>
# <p class="right-rail-article__time">2 hours ago</p>
# </div>
# <img alt="" class="js-content-image right-rail-article__thumb" data-src="https://cms.accuweather.com/wp-content/uploads/2024/06/SatSeverePlains6Jun.jpg?w=64&amp;h=64&amp;crop=1"/>
# </a>
# <a class="right-rail-article right-rail-ga" data-ga-action="Right Rail Click Editorial" data-ga-display-type="RightRailThumbnail" data-ga-label="At least 1 person is dead after tornado sweeps through DC suburbs" data-ga-section="Top Stories" href="https://www.accuweather.com/en/severe-weather/1-dead-homes-damaged-after-destructive-tornadoes-and-storms-hit-three-states-and-a-dc-suburb/1657107">
# <div class="right-rail-article__meta">
# <p class="right-rail-article__category">Severe Weather</p>
# <p class="right-rail-article__title">At least 1 person is dead after tornado sweeps through DC suburbs</p>
# <p class="right-rail-article__time">22 hours ago</p>
# </div>
# <img alt="" class="js-content-image right-rail-article__thumb" data-src="https://cms.accuweather.com/wp-content/uploads/2024/06/Screenshot-2024-06-05-at-10.28.40-PM.png?w=64&amp;h=64&amp;crop=1"/>
# </a>
# <a class="right-rail-article right-rail-ga" data-ga-action="Right Rail Click Editorial" data-ga-display-type="RightRailThumbnail" data-ga-label="A pause on summer temps, humidity as cooler air expands eastward" data-ga-section="Top Stories" href="https://www.accuweather.com/en/weather-forecasts/a-pause-on-summer-temps-humidity-as-cooler-air-expands-into-eastern-us/1656891">
# <div class="right-rail-article__meta">
# <p class="right-rail-article__category">Weather Forecasts</p>
# <p class="right-rail-article__title">A pause on summer temps, humidity as cooler air expands eastward</p>
# <p class="right-rail-article__time">1 hour ago</p>
# </div>
# <img alt="" class="js-content-image right-rail-article__thumb" data-src="https://cms.accuweather.com/wp-content/uploads/2024/06/SummerPauseFriToMonEast5Jun.jpg?w=64&amp;h=64&amp;crop=1"/>
# </a>
# <a class="right-rail-article right-rail-ga" data-ga-action="Right Rail Click Editorial" data-ga-display-type="RightRailThumbnail" data-ga-label="SpaceX Starship reaches new heights in latest launch" data-ga-section="Top Stories" href="https://www.accuweather.com/en/space-news/spacex-starship-reaches-new-heights-in-latest-launch/1657270">
# <div class="right-rail-article__meta">
# <p class="right-rail-article__category">Astronomy</p>
# <p class="right-rail-article__title">SpaceX Starship reaches new heights in latest launch</p>
# <p class="right-rail-article__time">21 hours ago</p>
# </div>
# <img alt="" class="js-content-image right-rail-article__thumb" data-src="https://cms.accuweather.com/wp-content/uploads/2024/06/GettyImages-2156353542.jpg?w=64&amp;h=64&amp;crop=1"/>
# </a>
# <a class="right-rail-article right-rail-ga" data-ga-action="Right Rail Click Editorial" data-ga-display-type="RightRailThumbnail" data-ga-label="Blistering heat wave to roast interior West into second week of June" data-ga-section="Top Stories" href="https://www.accuweather.com/en/weather-forecasts/blistering-heat-wave-to-have-interior-west-searing-into-second-week-of-june/1656973">
# <div class="right-rail-article__meta">
# <p class="right-rail-article__category">Weather Forecasts</p>
# <p class="right-rail-article__title">Blistering heat wave to roast interior West into second week of June</p>
# <p class="right-rail-article__time">2 hours ago</p>
# </div>
# <img alt="" class="js-content-image right-rail-article__thumb" data-src="https://cms.accuweather.com/wp-content/uploads/2024/06/RFFridayWest6Jun.jpg?w=64&amp;h=64&amp;crop=1"/>
# </a>
# <a class="cta" href="https://www.accuweather.com/en/weather-news">More Stories</a>
# </div>
# </div>
# <div class="glacier-ad unrendered bottom_right config-bottom_right content-module" data-ad-type="bottom_right" data-viewport="tablet desktop" id="bottom_right"></div>
# <div class="zone-rightRail2 content-module">
# <div class="thumbnail-right-rail">
# <p class="title">Featured Stories</p>
# <a class="right-rail-article right-rail-ga" data-ga-action="Right Rail Click Editorial" data-ga-display-type="RightRailThumbnail" data-ga-label="D-Day anniversary: How the weather forecast changed the tide of war" data-ga-section="Featured Stories" href="https://www.accuweather.com/en/weather-news/d-day-anniversary-how-the-weather-forecast-changed-the-tide-of-war/359733">
# <div class="right-rail-article__meta">
# <p class="right-rail-article__category">Weather News</p>
# <p class="right-rail-article__title">D-Day anniversary: How the weather forecast changed the tide of war</p>
# <p class="right-rail-article__time">3 days ago</p>
# </div>
# <img alt="" class="js-content-image right-rail-article__thumb" data-src="https://cms.accuweather.com/wp-content/uploads/2017/06/d-day-2.jpg?w=64&amp;h=64&amp;crop=1"/>
# </a>
# <a class="right-rail-article right-rail-ga" data-ga-action="Right Rail Click Editorial" data-ga-display-type="RightRailThumbnail" data-ga-label="Activists in South Korea send balloons back to North Korea" data-ga-section="Featured Stories" href="https://www.accuweather.com/en/weather-news/north-korea-sent-trash-balloons-to-south-korea-activists-are-sending-balloons-back-with-k-pop-and-k-dramas/1657186">
# <div class="right-rail-article__meta">
# <p class="right-rail-article__category">Weather News</p>
# <p class="right-rail-article__title">Activists in South Korea send balloons back to North Korea</p>
# <p class="right-rail-article__time">22 hours ago</p>
# </div>
# <img alt="" class="js-content-image right-rail-article__thumb" data-src="https://cms.accuweather.com/wp-content/uploads/2024/06/cnn-L19jb21wb25lbnRzL2ltYWdlL2luc3RhbmNlcy9jbHgyd2liaG8wMDFnM2I2aHJ1OHUxdnVn-L19jb21wb25lbnRzL2FydGljbGUvaW5zdGFuY2VzL2NseDJzbXI0YTAwMG5udnA0YTRpMzhobmE.jpg?w=64&amp;h=64&amp;crop=1"/>
# </a>
# <a class="right-rail-article right-rail-ga" data-ga-action="Right Rail Click Editorial" data-ga-display-type="RightRailThumbnail" data-ga-label="WHO confirms man's death from bird flu strain never seen in humans" data-ga-section="Featured Stories" href="https://www.accuweather.com/en/health-wellness/who-confirms-mexico-mans-death-from-bird-flu-strain-never-before-seen-in-humans/1657167">
# <div class="right-rail-article__meta">
# <p class="right-rail-article__category">Health</p>
# <p class="right-rail-article__title">WHO confirms man's death from bird flu strain never seen in humans</p>
# <p class="right-rail-article__time">1 day ago</p>
# </div>
# <img alt="" class="js-content-image right-rail-article__thumb" data-src="https://cms.accuweather.com/wp-content/uploads/2024/06/WHO-confirms-Mexico-mans-death-from-bird-flu-strain-never-before-seen-in-humans.jpg?w=64&amp;h=64&amp;crop=1"/>
# </a>
# <a class="right-rail-article right-rail-ga" data-ga-action="Right Rail Click Editorial" data-ga-display-type="RightRailThumbnail" data-ga-label="Deadly tornadoes tear through South Africa, killing 11" data-ga-section="Featured Stories" href="https://www.accuweather.com/en/weather-news/deadly-tornadoes-tear-through-south-africa-killing-11/1657030">
# <div class="right-rail-article__meta">
# <p class="right-rail-article__category">Weather News</p>
# <p class="right-rail-article__title">Deadly tornadoes tear through South Africa, killing 11</p>
# <p class="right-rail-article__time">1 day ago</p>
# </div>
# <img alt="" class="js-content-image right-r

# %%
# extract text
weather_data = []
for tag in soup.find_all(['h1', 'h2', 'h3', 'p']):
    text = tag.get_text(" ", strip=True)
    weather_data.append(text)

# combine all elements into a single string
weather_data = "\n".join(weather_data)

# remove all spaces from the combined text
weather_data = re.sub(r'\s+', ' ', weather_data)
    
print(f"Website: {url}\n\n")
print(weather_data)
# Out:
# Website: https://www.accuweather.com/en/ca/montreal/h3a/weather-today/56186
#
#
# Montreal, Quebec Montreal Quebec Around the Globe Around the Globe Hurricane Tracker Severe Weather Radar & Maps News & Features Astronomy Business Climate Health Recreation Sports Travel Video Winter Center Day Max UV Index 4 Moderate Wind SW 11 km/h Wind Gusts 35 km/h Probability of Precipitation 84% Probability of Thunderstorms 26% Precipitation 7.9 mm Rain 7.9 mm Hours of Precipitation 4 Hours of Rain 4 Cloud Cover 76% Morning Afternoon Night Wind WSW 9 km/h Wind Gusts 33 km/h Probability of Precipitation 40% Probability of Thunderstorms 8% Precipitation 0.5 mm Rain 0.5 mm Hours of Precipitation 1 Hours of Rain 1 Cloud Cover 25% Evening Overnight Sun & Moon Temperature History Further Ahead Further Ahead Hourly Daily Monthly Around the Globe Around the Globe Hurricane Tracker Severe Weather Radar & Maps News Video Winter Center Top Stories Severe Weather Severe storms and downpours to return to south-central US 2 hours ago Severe Weather At least 1 person is dead after tornado sweeps through DC suburbs 22 hours ago Weather Forecasts A pause on summer temps, humidity as cooler air expands eastward 1 hour ago Astronomy SpaceX Starship reaches new heights in latest launch 21 hours ago Weather Forecasts Blistering heat wave to roast interior West into second week of June 2 hours ago Featured Stories Weather News D-Day anniversary: How the weather forecast changed the tide of war 3 days ago Weather News Activists in South Korea send balloons back to North Korea 22 hours ago Health WHO confirms man's death from bird flu strain never seen in humans 1 day ago Weather News Deadly tornadoes tear through South Africa, killing 11 1 day ago Hurricane Long path to identifying woman who disappeared in Hurricane Katrina 1 day ago Weather Near Montreal: We have updated our Privacy Policy and Cookie Policy . Get AccuWeather alerts as they happen with our browser notifications. Notifications Enabled Thanks! We’ll keep you informed.

# %% [markdown]
# # Using the agentic search

# %%
# run search
result = client.search(query, max_results=1)

# print first result
data = result["results"][0]["content"]

print(data)
# Out:
# {'location': {'name': 'Montreal', 'region': 'Quebec', 'country': 'Canada', 'lat': 45.5, 'lon': -73.58, 'tz_id': 'America/Toronto', 'localtime_epoch': 1717764644, 'localtime': '2024-06-07 8:50'}, 'current': {'last_updated_epoch': 1717764300, 'last_updated': '2024-06-07 08:45', 'temp_c': 19.1, 'temp_f': 66.4, 'is_day': 1, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png', 'code': 1003}, 'wind_mph': 8.1, 'wind_kph': 13.0, 'wind_degree': 250, 'wind_dir': 'WSW', 'pressure_mb': 999.0, 'pressure_in': 29.51, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 83, 'cloud': 25, 'feelslike_c': 19.1, 'feelslike_f': 66.4, 'windchill_c': 17.5, 'windchill_f': 63.5, 'heatindex_c': 17.5, 'heatindex_f': 63.5, 'dewpoint_c': 13.8, 'dewpoint_f': 56.9, 'vis_km': 24.0, 'vis_miles': 14.0, 'uv': 5.0, 'gust_mph': 9.8, 'gust_kph': 15.7}}

# %%
import json
from pygments import highlight, lexers, formatters

# parse JSON
parsed_json = json.loads(data.replace("'", '"'))

# pretty print JSON with syntax highlighting
formatted_json = json.dumps(parsed_json, indent=4)
colorful_json = highlight(formatted_json,
                          lexers.JsonLexer(),
                          formatters.TerminalFormatter())

print(colorful_json)
# Out:
# {
#     "location": {
#         "name": "Montreal",
#         "region": "Quebec",
#         "country": "Canada",
#         "lat": 45.5,
#         "lon": -73.58,
#         "tz_id": "America/Toronto",
#         "localtime_epoch": 1717764644,
#         "localtime": "2024-06-07 8:50"
#     },
#     "current": {
#         "last_updated_epoch": 1717764300,
#         "last_updated": "2024-06-07 08:45",
#         "temp_c": 19.1,
#         "temp_f": 66.4,
#         "is_day": 1,
#         "condition": {
#             "text": "Partly cloudy",
#             "icon": "//cdn.weatherapi.com/weather/64x64/day/116.png",
#             "code": 1003
#         },
#         "wind_mph": 8.1,
#         "wind_kph": 13.0,
#         "wind_degree": 250,
#         "wind_dir": "WSW",
#         "pressure_mb": 999.0,
#         "pressure_in": 29.51,
#         "precip_mm": 0.0,
#         "precip_in": 0.0,
#         "humidity": 83,
#         "cloud": 25,
#         "feelslike_c": 19.1,
#         "feelslike_f": 66.4,
#         "windchill_c": 17.5,
#         "windchill_f": 63.5,
#         "heatindex_c": 17.5,
#         "heatindex_f": 63.5,
#         "dewpoint_c": 13.8,
#         "dewpoint_f": 56.9,
#         "vis_km": 24.0,
#         "vis_miles": 14.0,
#         "uv": 5.0,
#         "gust_mph": 9.8,
#         "gust_kph": 15.7
#     }
# }
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
